# %% [markdown]
# # Primer entorno de Python

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
#Esto es un comentario

# %%
def function():
    """
    Comentario de varias lineas
    Argumentos:
    -
    -
    resultados
    """

# %%
print('3') #Imprime le numero 3
# Out:
# 3

# %%
#Validacion de numero (Comentarios en bloque)
if 2<3:
    print('2 es menor que 3')
# Out:
# 2 es menor que 3

# %% [markdown]
# # Variables

# %%
caja1 = 123

# %%
variable = 4.0

nombre = 'Leonidas'

edad =10

# %%
print(edad)
print(nombre)
# Out:
# 10
# Leonidas

# %%
type(edad)
# Out:
# int

# %%
a = str('4')
b = int('5')
c= float('2.3')

# %%
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 2.3

# %%
x,y,z='orange','chery' , 'Banana'

# %%
print(x)
print(y)
print(z)
# Out:
# orange
# chery
# Banana

# %%
a = b= c = 12

# %%
print(a)
print(b)
print(c)
# Out:
# 12
# 12
# 12

# %% [markdown]
# # Tipos de Datos

# %%
#String
nombres = 'Leonidas'
print(nombres)
# Out:
# Leonidas

# %%
nombres[2:5]
# Out:
# 'oni'

# %% [markdown]
# # Numericos

# %%
int_num = 10
float_num = 10.2
complex_num=12.j

# %%
complex_num
# Out:
# 12j

# %% [markdown]
# # Listas

# %%
#Colocando mis elemento en []
my_list_1 = [3,5,2]
print(my_list_1)

my_list_2 = []
print(my_list_2)

my_list_3 = [3,'Hola',44.4]
print(my_list_3)


#Lista anidada
my_list_4 = ["apple'",[3,'Hika',44.4],38]
print(my_list_4)
# Out:
# [3, 5, 2]
# []
# [3, 'Hola', 44.4]
# ["apple'", [3, 'Hika', 44.4], 38]

# %%
my_list_4.insert(1,30)

# %%
print(my_list_4)
# Out:
# ["apple'", 30, [3, 'Hika', 44.4], 38]

# %%
my_list = ['x','l','m','n']
#Primer elemento
print(my_list[1])

#Segundo elemento
print(my_list[2])


#Tercer elemento
print(my_list[3])
# Out:
# l
# m
# n

# %%
#Lista anidada
n_list = ['Happy',[6,2,1],4]

print(n_list[0][2])
print(n_list[1][2])

n_list[0]='r'


print(n_list)
# Out:
# p
# 1
# ['r', [6, 2, 1], 4]

# %% [markdown]
# # Tuple Data

# %%
#Definir una tupla
my_tuple = ()
print(my_tuple)

#tuple de int
my_tuple = (3,2,4)
print (my_tuple)

#Tuple mixta
my_tuple = (3,'Hello',4.7)
print(my_tuple)

#Tupla anidada
my_tuple = (3,'Hello', [3,'hello', 4])
print=(my_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 3
#       1 #Definir una tupla
#       2 my_tuple = ()
# ----> 3 print(my_tuple)
#       5 #tuple de int
#       6 my_tuple = (3,2,4)
#
# TypeError: 'tuple' object is not callable

# %%
frutas = ['apple','banana','mango']

for fruta in frutas:
    print('I like',fruta)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 4
#       1 frutas = ['apple','banana','mango']
#       3 for fruta in frutas:
# ----> 4     print('I like',fruta)
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# # Diccionario

# %%
#Diccionario vacio
my_dict = {}

my_dict_2 = {
    1: 'apple',
    2:'Pera'
}


print (my_dict_2)
# Out:
# {1: 'apple', 2: 'Pera'}

# %%
estudiante = {
    'estudiante_01 ' :{
     'Nombre':'Leonidas',
     'Apellido':'Sanchez'
    },
    'estudiante_02 ' :{
     'Nombre':'Leonidas',
     'Apellido':'Sanchez'
    }
    }



print(estudiante)
# Out:
# {'estudiante_01 ': {'Nombre': 'Leonidas', 'Apellido': 'Sanchez'}, 'estudiante_02 ': {'Nombre': 'Leonidas', 'Apellido': 'Sanchez'}}

# %%
print(estudiante['estudiante_02 '])
print(estudiante.get('estudiante_02 '))
# Out:
# {'Nombre': 'Leonidas', 'Apellido': 'Sanchez'}
# {'Nombre': 'Leonidas', 'Apellido': 'Sanchez'}

# %%
print (estudiante.values())
print (estudiante.keys())
# Out:
# dict_values([{'Nombre': 'Leonidas', 'Apellido': 'Sanchez'}, {'Nombre': 'Leonidas', 'Apellido': 'Sanchez'}])
# dict_keys(['estudiante_01 ', 'estudiante_02 '])
